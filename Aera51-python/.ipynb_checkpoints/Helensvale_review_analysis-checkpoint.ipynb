# %%
import sys
# !{sys.executable} -m pip install pandas openpyxl wordcloud matplotlib
# Out:
# ...
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# ...
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [openpyxl]━━ 1/2 [openpyxl]
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: /Users/gama/venvs/reviews/bin/python -m pip install --upgrade pip

# %%
import pandas as pd
import matplotlib.pyplot as plt
import re
from IPython.display import display, Markdown
from wordcloud import WordCloud, STOPWORDS
from pathlib import Path

file_path = Path(
    "data/Area 51 Helensvale_SurveyResponse_220420261426_919949806.xlsx"
)

df = pd.read_excel(
    file_path,
    sheet_name="GXS"
)

# Convert the date column
df["Completed Date"] = pd.to_datetime(
    df["Completed Date"],
    errors="coerce"
)

# Dataset information
total_rows = len(df)
unique_bookings = df["Booking ID"].nunique(dropna=True)
first_date = df["Completed Date"].min()
last_date = df["Completed Date"].max()

# Rating columns
rating_columns = {
    "Overall": "Overall Rating",
    "Service": "Service Rating",
    "Safety": "Safety Rating",
    "Facilities": "Facilities Rating",
    "Value": "Value Rating"
}

# Make sure ratings are numeric
for column in rating_columns.values():
    df[column] = pd.to_numeric(df[column], errors="coerce")

# Create rating summary table
rating_summary = pd.DataFrame([
    {
        "Area": area,
        "Average": f"{df[column].mean():.2f} / 5",
        "Responses": f"{df[column].count():,}"
    }
    for area, column in rating_columns.items()
])

# Display the text summary
display(Markdown(
    f"""
## Area 51 Helensvale Survey Summary

The spreadsheet contains **{total_rows:,} rows** and approximately **{unique_bookings:,} unique bookings**.

The survey data covers **{first_date.strftime('%d %B %Y')}** to **{last_date.strftime('%d %B %Y')}**.

### Rating Averages
"""
))

# Display the table
display(rating_summary)
display(df.head())
# Out:
# ## Area 51 Helensvale Survey Summary
#
# The spreadsheet contains **15,875 rows** and approximately **15,736 unique bookings**.
#
# The survey data covers **26 July 2025** to **22 April 2026**.
#
# ### Rating Averages
#          Area   Average Responses
# 0     Overall  4.11 / 5     1,891
# 1     Service  4.22 / 5     1,539
# 2      Safety  4.19 / 5     1,515
# 3  Facilities  4.25 / 5     1,527
# 4       Value  3.93 / 5     1,529
#          Full Name                      Email   Booking ID Comments    Fan  \
# 0    Leah Thompson  leahlonorgan743@gmail.com  105035526.0      NaN  False
# 1      Sophie Wake         gswake@hotmail.com  105035296.0      NaN  False
# 2  Roni Isam Mekha  hannoshgroup.au@gmail.com  105029931.0      NaN  False
# 3    Zhuona Zhuona       zhuona77@outlook.com  105032796.0      NaN  False
# 4  Chelsea Edwards     chlsea.jones@gmail.com  105032168.0      NaN  False
#
#    Critic  Overall Rating  Overall Rating Reasons  Service Rating  \
# ...

# %%
text_columns = [
    "Comments",
    "Overall Rating Reasons",
    "Service Rating Reasons",
    "Safety Rating Reasons",
    "Facilities Rating Reasons",
    "Value Rating Reasons",
    "Additional Question Comment",
    "Additional Question Answers"
]

available_columns = [
    column for column in text_columns
    if column in df.columns
]

non_empty_counts = (
    df[available_columns]
    .notna()
    .sum()
    .sort_values(ascending=False)
)

display(non_empty_counts)
# Out:
# Service Rating Reasons         928
# Value Rating Reasons           890
# Facilities Rating Reasons      841
# Safety Rating Reasons          827
# Additional Question Answers    791
# Comments                       572
# Additional Question Comment    193
# Overall Rating Reasons           0
# dtype: int64

# %%
# Combine the selected feedback columns
combined_rows = (
    df[available_columns]
    .fillna("")
    .astype(str)
    .agg(" ".join, axis=1)
)

text = " ".join(combined_rows)


text = text.lower()
text = re.sub(r"[^a-zA-Z\s']", " ", text)
text = re.sub(r"\s+", " ", text).strip()

# %%
custom_stopwords = set(STOPWORDS)

# Add words that may appear frequently but provide little insight
custom_stopwords.update({
    "area",
    "area51",
    "helensvale",
    "one",
    "really",
    "would",
    "could",
    "also",
    "get",
    "got",
    "still",
    "thing",
    "place",
    "went"
})

wordcloud = WordCloud(
    width=1600,
    height=900,
    background_color="white",
    stopwords=custom_stopwords,
    collocations=False,
    max_words=150,
    min_font_size=10,
    random_state=42
).generate(text)

plt.figure(figsize=(16, 9))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.title(
    "Area 51 Helensvale Survey Feedback Word Cloud",
    fontsize=20,
    pad=20
)
plt.tight_layout()
plt.show()

# %%
from sklearn.feature_extraction.text import CountVectorizer
from wordcloud import WordCloud
import pandas as pd
import matplotlib.pyplot as plt


def create_phrase_cloud(
    input_text,
    title,
    phrase_lengths=(2, 3),
    minimum_occurrences=2,
    max_phrases=150,
    stop_phrases=None
):
    """
    Create a cloud of repeated phrases.

    stop_phrases removes unwanted exact phrases.
    """

    if not isinstance(input_text, str) or not input_text.strip():
        print(f"No text found for: {title}")
        return None

    if stop_phrases is None:
        stop_phrases = set()

    # Standardise stop phrases
    stop_phrases = {
        phrase.lower().strip()
        for phrase in stop_phrases
    }

    vectorizer = CountVectorizer(
        ngram_range=phrase_lengths,
        stop_words=list(custom_stopwords),
        token_pattern=r"(?u)\b[a-zA-Z][a-zA-Z']+\b"
    )

    phrase_matrix = vectorizer.fit_transform([input_text])

    phrases = vectorizer.get_feature_names_out()
    counts = phrase_matrix.toarray()[0]

    phrase_frequencies = {
        phrase: int(count)
        for phrase, count in zip(phrases, counts)

        # Minimum frequency
        if count >= minimum_occurrences

        # Remove exact stop phrases
        and phrase.lower().strip() not in stop_phrases
    }

    phrase_frequencies = dict(
        sorted(
            phrase_frequencies.items(),
            key=lambda item: item[1],
            reverse=True
        )[:max_phrases]
    )

    if not phrase_frequencies:
        print(
            f"No phrases appeared at least "
            f"{minimum_occurrences} times."
        )
        return None

    phrase_cloud = WordCloud(
        width=1600,
        height=900,
        background_color="white",
        max_words=max_phrases,
        collocations=False,
        random_state=42
    ).generate_from_frequencies(phrase_frequencies)

    plt.figure(figsize=(16, 9))
    plt.imshow(phrase_cloud, interpolation="bilinear")
    plt.axis("off")
    plt.title(title, fontsize=20, pad=20)
    plt.tight_layout()
    plt.show()

    phrase_table = pd.DataFrame(
        phrase_frequencies.items(),
        columns=["Phrase", "Occurrences"]
    )

    return phrase_table

# %%
survey_phrase_table = create_phrase_cloud(
    input_text=text,
    title="Common Phrases in Survey Feedback",
    phrase_lengths=(2, 3),
    minimum_occurrences=3
)

if survey_phrase_table is not None:
    display(survey_phrase_table.head(30))
# Out:
#                           Phrase  Occurrences
# 0             facebook instagram          130
# 1             recommended friend          123
# 2                   social media          119
# 3       helpfulness friendliness          104
# 4        maintenance facilityage          102
# 5            hygiene cleanliness          101
# 6          cleanliness equipment           97
# 7        facilityage temperature           91
# 8       friendliness helpfulness           89
# 9        facilityage maintenance           85
# 10       maintenance temperature           85
# 11       temperature facilityage           84
# 12      friendliness cleanliness           82
# 13  professionalism friendliness           82
# 14        variety familyfriendly           81
# 15         equipment cleanliness           79
# 16           cleanliness hygiene           78
# 17        familyfriendly variety           75
# 18  friendliness professionalism           73
# ...

# %%
word_frequency = (
    pd.DataFrame(
        wordcloud.words_.items(),
        columns=["Word", "Relative Frequency"]
    )
    .sort_values(
        "Relative Frequency",
        ascending=False
    )
    .reset_index(drop=True)
)

display(word_frequency.head(30))
# Out:
#                Word  Relative Frequency
# 0      friendliness            1.000000
# 1       cleanliness            0.909798
# 2           variety            0.833593
# 3       maintenance            0.791602
# 4              food            0.786936
# 5       facilityage            0.762053
# 6       helpfulness            0.737170
# 7       temperature            0.656299
# 8   professionalism            0.642302
# 9          capacity            0.640747
# 10        efficient            0.618974
# 11        equipment            0.601866
# 12   familyfriendly            0.598756
# 13          hygiene            0.556765
# 14      supervision            0.548989
# 15    consideration            0.493002
# 16          parking            0.455677
# 17              kid            0.441680
# 18      instruction            0.413686
# 19        knowledge            0.390358
# 20         patience            0.387247
# 21          quality            0.385692
# ...

# %%
# Service Rating Reasons         928
# Value Rating Reasons           890
# Facilities Rating Reasons      841
# Safety Rating Reasons          827
# Additional Question Answers    791
# Comments                       572
# Additional Question Comment    193
# Overall Rating Reasons           0

column_name = "Comments"

single_column_text = " ".join(
    df[column_name]
    .dropna()
    .astype(str)
)

single_column_text = single_column_text.lower()
single_column_text = re.sub(
    r"[^a-zA-Z\s']",
    " ",
    single_column_text
)
single_column_text = re.sub(
    r"\s+",
    " ",
    single_column_text
).strip()

wordcloud = WordCloud(
    width=1600,
    height=900,
    background_color="white",
    stopwords=custom_stopwords,
    collocations=False,
    max_words=150,
    random_state=42,
).generate(single_column_text)

plt.figure(figsize=(16, 9))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.title(column_name)
plt.tight_layout()
plt.show()

# %%
comment_stop_phrases = {
    "area 51",
    "thank you",
    "will definitely",
    "year olds",
    "year old"
}

comment_phrase_table = create_phrase_cloud(
    input_text=single_column_text,
    title="Common Phrases in Customer Comments",
    phrase_lengths=(2, 3),
    minimum_occurrences=2,
    stop_phrases=comment_stop_phrases
)

display(comment_phrase_table.head(30))
# Out:
#                   Phrase  Occurrences
# 0               ball pit           19
# 1             grip socks           19
# 2             older kids           19
# 3             party host           19
# 4           staff member           18
# 5             great time           11
# 6         older children           10
# 7            even though            9
# 8             front desk            9
# 9     overall experience            9
# 10            first time            8
# 11            great kids            8
# 12             month old            8
# 13        purchase socks            8
# 14         staff amazing            8
# 15        staff friendly            8
# 16             buy socks            7
# 17       definitely back            7
# 18      great experience            7
# 19            kids great            7
# 20            kids loved            7
# 21           little kids            7
# 22           play centre            7
# 23          staff lovely            7
# ...

# %%
df["Completed Date"] = pd.to_datetime(
    df["Completed Date"],
    errors="coerce"
)

rating_columns = [
    "Overall Rating",
    "Service Rating",
    "Safety Rating",
    "Facilities Rating",
    "Value Rating"
]

# Ensure ratings are numeric
for column in rating_columns:
    df[column] = pd.to_numeric(
        df[column],
        errors="coerce"
    )

print("First survey date:", df["Completed Date"].min())
print("Latest survey date:", df["Completed Date"].max())
# Out:
# First survey date: 2025-07-26 00:00:00
# Latest survey date: 2026-04-22 00:00:00

# %%
monthly_ratings = (
    df
    .set_index("Completed Date")[rating_columns]
    .resample("MS")
    .agg(["mean", "count"])
)

display(monthly_ratings)
# Out:
#                Overall Rating       Service Rating       Safety Rating        \
#                          mean count           mean count          mean count
# Completed Date
# 2025-07-01           4.045455   110       4.138298    94      4.197802    91
# 2025-08-01           4.032328   464       4.176781   379      4.066138   378
# 2025-09-01           4.229008   262       4.367647   204      4.411765   204
# 2025-10-01           4.100719   139       4.238938   113      4.252252   111
# 2025-11-01           4.060773   181       4.174497   149      4.183099   142
# 2025-12-01           4.083871   155       4.114504   131      4.178295   129
# 2026-01-01           4.084112   214       4.091954   174      4.117647   170
# 2026-02-01           4.140351   114       4.384615    91      4.147727    88
# 2026-03-01           4.125000   128       4.141509   106      4.180952   105
# 2026-04-01           4.290323   124       4.428571    98      4.371134    97
#
# ...

# %%
plt.figure(figsize=(16, 8))

for column in rating_columns:
    plt.plot(
        monthly_average.index,
        monthly_average[column],
        marker="o",
        linewidth=2,
        label=column.replace(" Rating", "")
    )

plt.axhline(y=4.0, linestyle="--", linewidth=1, label="Target 4.0")
plt.title("Average Customer Ratings by Month", fontsize=16)
plt.xlabel("Month")
plt.ylabel("Average Rating")
plt.ylim(3.7, 4.5)
plt.grid(alpha=0.3)
plt.xticks(rotation=45)
plt.legend(bbox_to_anchor=(1.02, 1), loc="upper left")
plt.tight_layout()
plt.show()

# %%
monthly_average = (
    df
    .set_index("Completed Date")[rating_columns]
    .resample("MS")
    .mean()
)

monthly_average = monthly_average.round(2)

monthly_counts = (
    df.set_index("Completed Date")["Overall Rating"]
      .resample("MS")
      .count()
)

fig, axes = plt.subplots(len(rating_columns), 1, figsize=(14, 16), sharex=True)

for ax, col in zip(axes, rating_columns):
    ax.plot(monthly_average.index, monthly_average[col], marker="o", linewidth=2)
    ax.axhline(y=4.0, linestyle="--", linewidth=1)
    ax.set_title(col, loc="left", fontsize=12)
    ax.set_ylabel("Avg")
    ax.set_ylim(3.5, 4.6)
    ax.grid(alpha=0.3)

axes[-1].set_xlabel("Month")
plt.xticks(rotation=45)
plt.suptitle("Monthly Customer Rating Trends", fontsize=16, y=0.98)
plt.tight_layout()
plt.show()

# %%
weekly_average = (
    df
    .set_index("Completed Date")[rating_columns]
    .resample("W-MON", label="left", closed="left")
    .mean()
    .round(2)
)

display(weekly_average.tail(20))
# Out:
#                 Overall Rating  Service Rating  Safety Rating  \
# Completed Date
# 2025-12-08                4.17            4.16           4.03
# 2025-12-15                3.91            4.16           4.23
# 2025-12-22                4.25            4.39           4.36
# 2025-12-29                3.98            4.09           4.21
# 2026-01-05                4.18            4.26           4.26
# 2026-01-12                4.12            3.88           3.95
# 2026-01-19                4.02            4.07           4.16
# 2026-01-26                4.32            4.35           4.26
# 2026-02-02                4.50            5.00           4.69
# 2026-02-09                4.03            4.52           4.16
# 2026-02-16                3.94            4.00           3.76
# 2026-02-23                4.00            4.12           3.83
# 2026-03-02                3.91            3.80           3.97
# 2026-03-09                4.13            4.36           4.23
# ...

# %%
plt.figure(figsize=(16, 7))

for column in rating_columns:
    plt.plot(
        weekly_average.index,
        weekly_average[column],
        marker="o",
        markersize=4,
        label=column
    )

plt.axhline(
    y=4,
    linestyle="--",
    linewidth=1,
    label="Target rating: 4.0"
)

plt.title("Average Customer Ratings by Week")
plt.xlabel("Week beginning")
plt.ylabel("Average Rating")
plt.ylim(1, 5.1)
plt.legend()
plt.grid(alpha=0.3)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
overall_data = (
    df[
        ["Completed Date", "Overall Rating"]
    ]
    .dropna()
    .set_index("Completed Date")
)

monthly_summary = (
    overall_data["Overall Rating"]
    .resample("MS")
    .agg(
        Average_Rating="mean",
        Responses="count",
        Top_Rating_Percentage=lambda values: (
            values.ge(4).mean() * 100
        )
    )
)

monthly_summary["Change_From_Previous_Month"] = (
    monthly_summary["Average_Rating"].diff()
)

monthly_summary = monthly_summary.round(2)

display(monthly_summary)
# Out:
#                 Average_Rating  Responses  Top_Rating_Percentage  \
# Completed Date
# 2025-07-01                4.05        110                  73.64
# 2025-08-01                4.03        464                  72.63
# 2025-09-01                4.23        262                  79.77
# 2025-10-01                4.10        139                  76.98
# 2025-11-01                4.06        181                  77.90
# 2025-12-01                4.08        155                  75.48
# 2026-01-01                4.08        214                  77.57
# 2026-02-01                4.14        114                  76.32
# 2026-03-01                4.12        128                  75.00
# 2026-04-01                4.29        124                  82.26
#
#                 Change_From_Previous_Month
# Completed Date
# 2025-07-01                             NaN
# 2025-08-01                           -0.01
# 2025-09-01                            0.20
# ...

# %%
plt.figure(figsize=(14, 5))

plt.bar(
    monthly_summary.index,
    monthly_summary["Responses"],
    width=20
)

plt.title("Number of Overall Ratings Received by Month")
plt.xlabel("Month")
plt.ylabel("Number of responses")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
text_columns = [
    "Comments",
    "Overall Rating Reasons",
    "Service Rating Reasons",
    "Safety Rating Reasons",
    "Facilities Rating Reasons",
    "Value Rating Reasons",
    "Additional Question Comment",
    "Additional Question Answers"
]

# Only use columns that actually exist
available_text_columns = [
    column for column in text_columns
    if column in df.columns
]

# Combine all comments from each survey row
df["Feedback Text"] = (
    df[available_text_columns]
    .fillna("")
    .astype(str)
    .agg(" ".join, axis=1)
    .str.lower()
)

# Remove rows without written feedback
feedback_df = df[
    df["Feedback Text"].str.strip().ne("")
].copy()

print(f"Rows containing written feedback: {len(feedback_df):,}")
# Out:
# Rows containing written feedback: 1,433

# %%
issue_keywords = {
    "Food": [
        r"\bfood\b",
        r"\bcafe\b",
        r"\bcoffee\b",
        r"\bdrink\b",
        r"\bdrinks\b",
        r"\bmenu\b",
        r"\bmeal\b",
        r"\bsnack\b",
        r"\bchips\b"
    ],

    "Socks": [
        r"\bsock\b",
        r"\bsocks\b",
        r"\bgrip socks?\b"
    ],

    "Toilets": [
        r"\btoilet\b",
        r"\btoilets\b",
        r"\bbathroom\b",
        r"\bbathrooms\b",
        r"\brestroom\b",
        r"\bwashroom\b"
    ],

    "Cleanliness": [
        r"\bclean\b",
        r"\bcleanliness\b",
        r"\bdirty\b",
        r"\bfilthy\b",
        r"\bhygiene\b",
        r"\bmess\b",
        r"\bmessy\b",
        r"\bsmell\b",
        r"\bsmelly\b",
        r"\brubbish\b",
        r"\btrash\b",
        r"\bbin\b",
        r"\bbins\b"
    ],

    "Staffing": [
        r"\bstaff\b",
        r"\bstaffing\b",
        r"\bunderstaffed\b",
        r"\bemployee\b",
        r"\bemployees\b",
        r"\bworker\b",
        r"\bworkers\b",
        r"\bsupervision\b",
        r"\bsupervisor\b"
    ],

    "Capacity": [
        r"\bcrowded\b",
        r"\bovercrowded\b",
        r"\bcapacity\b",
        r"\btoo busy\b",
        r"\bbusy\b",
        r"\bpacked\b",
        r"\btoo many people\b",
        r"\btoo many kids\b",
        r"\bqueue\b",
        r"\bqueues\b",
        r"\bwaiting\b",
        r"\bwait time\b",
        r"\blong wait\b"
    ],

    "Value": [
        r"\bvalue\b",
        r"\bprice\b",
        r"\bprices\b",
        r"\bpricing\b",
        r"\bcost\b",
        r"\bcosts\b",
        r"\bexpensive\b",
        r"\boverpriced\b",
        r"\btoo much\b",
        r"\bworth\b",
        r"\bmoney\b",
        r"\bfee\b",
        r"\bfees\b"
    ]
}

# %%
for issue, keywords in issue_keywords.items():
    pattern = "|".join(keywords)

    feedback_df[f"{issue} Mention"] = (
        feedback_df["Feedback Text"]
        .str.contains(pattern, regex=True, na=False)
    )

issue_summary = pd.DataFrame([
    {
        "Issue": issue,
        "Mentions": int(feedback_df[f"{issue} Mention"].sum()),
        "Percentage of Feedback": (
            feedback_df[f"{issue} Mention"].mean() * 100
        )
    }
    for issue in issue_keywords
])

issue_summary = (
    issue_summary
    .sort_values("Mentions", ascending=False)
    .reset_index(drop=True)
)

display(
    issue_summary.style
    .format({
        "Mentions": "{:,}",
        "Percentage of Feedback": "{:.1f}%"
    })
    .hide(axis="index")
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_d959e">
#   <thead>
#     <tr>
#       <th id="T_d959e_level0_col0" class="col_heading level0 col0" >Issue</th>
#       <th id="T_d959e_level0_col1" class="col_heading level0 col1" >Mentions</th>
#       <th id="T_d959e_level0_col2" class="col_heading level0 col2" >Percentage of Feedback</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d959e_row0_col0" class="data row0 col0" >Cleanliness</td>
#       <td id="T_d959e_row0_col1" class="data row0 col1" >654</td>
#       <td id="T_d959e_row0_col2" class="data row0 col2" >45.6%</td>
#     </tr>
#     <tr>
#       <td id="T_d959e_row1_col0" class="data row1 col0" >Staffing</td>
#       <td id="T_d959e_row1_col1" class="data row1 col1" >463</td>
#       <td id="T_d959e_row1_col2" class="data row1 col2" >32.3%</td>
#     </tr>
#     <tr>
#       <td id="T_d959e_row2_col0" class="data row2 col0" >Food</td>
# ...

# %%
negative_keywords = [
    r"\bbad\b",
    r"\bpoor\b",
    r"\bterrible\b",
    r"\bawful\b",
    r"\bdisappointing\b",
    r"\bdisappointed\b",
    r"\bdirty\b",
    r"\bfilthy\b",
    r"\bexpensive\b",
    r"\boverpriced\b",
    r"\brude\b",
    r"\bunhelpful\b",
    r"\bslow\b",
    r"\blong wait\b",
    r"\bnot enough\b",
    r"\bunderstaffed\b",
    r"\bcrowded\b",
    r"\bovercrowded\b",
    r"\bpacked\b",
    r"\bproblem\b",
    r"\bissue\b",
    r"\bcomplaint\b",
    r"\bneeds improvement\b",
    r"\bneed improvement\b",
    r"\bshould improve\b",
    r"\btoo much\b",
    r"\btoo many\b",
    r"\bnot clean\b",
    r"\bnot worth\b",
    r"\bno staff\b",
    r"\black of\b"
]

negative_pattern = "|".join(negative_keywords)

feedback_df["Negative Language"] = (
    feedback_df["Feedback Text"]
    .str.contains(negative_pattern, regex=True, na=False)
)

# %%
negative_issue_summary = pd.DataFrame([
    {
        "Issue": issue,

        "All Mentions": int(
            feedback_df[f"{issue} Mention"].sum()
        ),

        "Likely Negative Mentions": int(
            (
                feedback_df[f"{issue} Mention"]
                & feedback_df["Negative Language"]
            ).sum()
        )
    }
    for issue in issue_keywords
])

negative_issue_summary["Negative Share"] = (
    negative_issue_summary["Likely Negative Mentions"]
    / negative_issue_summary["All Mentions"]
    * 100
)

negative_issue_summary = (
    negative_issue_summary
    .sort_values(
        "Likely Negative Mentions",
        ascending=False
    )
    .reset_index(drop=True)
)

display(
    negative_issue_summary.style
    .format({
        "All Mentions": "{:,}",
        "Likely Negative Mentions": "{:,}",
        "Negative Share": "{:.1f}%"
    })
    .hide(axis="index")
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_16303">
#   <thead>
#     <tr>
#       <th id="T_16303_level0_col0" class="col_heading level0 col0" >Issue</th>
#       <th id="T_16303_level0_col1" class="col_heading level0 col1" >All Mentions</th>
#       <th id="T_16303_level0_col2" class="col_heading level0 col2" >Likely Negative Mentions</th>
#       <th id="T_16303_level0_col3" class="col_heading level0 col3" >Negative Share</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_16303_row0_col0" class="data row0 col0" >Cleanliness</td>
#       <td id="T_16303_row0_col1" class="data row0 col1" >654</td>
#       <td id="T_16303_row0_col2" class="data row0 col2" >102</td>
#       <td id="T_16303_row0_col3" class="data row0 col3" >15.6%</td>
#     </tr>
#     <tr>
#       <td id="T_16303_row1_col0" class="data row1 col0" >Food</td>
#       <td id="T_16303_row1_col1" class="data row1 col1" >447</td>
#       <td id="T_16303_row1_col2" class="data row1 col2" >96</td>
# ...

# %%
top_issue = negative_issue_summary.iloc[0]

display(Markdown(
    f"""
## Recurring Issue Analysis

A total of **{len(feedback_df):,} survey rows** contained written feedback.

The most frequently detected negative issue was **{top_issue['Issue']}**, with approximately  
**{top_issue['Likely Negative Mentions']:,.0f} likely negative mentions**.

The table below ranks food, socks, toilets, cleanliness, staffing, capacity and value according to the number of likely complaint-related mentions.
"""
))

display(
    negative_issue_summary.style
    .format({
        "All Mentions": "{:,}",
        "Likely Negative Mentions": "{:,}",
        "Negative Share": "{:.1f}%"
    })
    .hide(axis="index")
)
# Out:
# ## Recurring Issue Analysis
#
# A total of **1,433 survey rows** contained written feedback.
#
# The most frequently detected negative issue was **Cleanliness**, with approximately
# **102 likely negative mentions**.
#
# The table below ranks food, socks, toilets, cleanliness, staffing, capacity and value according to the number of likely complaint-related mentions.
# <style type="text/css">
# </style>
# <table id="T_77141">
#   <thead>
#     <tr>
#       <th id="T_77141_level0_col0" class="col_heading level0 col0" >Issue</th>
#       <th id="T_77141_level0_col1" class="col_heading level0 col1" >All Mentions</th>
#       <th id="T_77141_level0_col2" class="col_heading level0 col2" >Likely Negative Mentions</th>
#       <th id="T_77141_level0_col3" class="col_heading level0 col3" >Negative Share</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_77141_row0_col0" class="data row0 col0" >Cleanliness</td>
# ...

# %%
# selected_issue = "Food"
# selected_issue = "Socks"
# selected_issue = "Cleanliness"
# selected_issue = "Staffing"
# selected_issue = "Capacity"
# selected_issue = "Value"
# selected_issue = "Toilets"

selected_issue = "Toilets"

toilet_comments = feedback_df.loc[
    feedback_df[f"{selected_issue} Mention"]
    & feedback_df["Negative Language"],
    [
        "Completed Date",
        "Booking ID",
        "Feedback Text"
    ]
].copy()

display(toilet_comments.head(20))
# Out:
#       Completed Date   Booking ID  \
# 1230      2026-03-29  102584358.0
# 1663      2026-04-04  104028600.0
# 1895      2026-02-28  102777233.0
# 4371      2025-12-14   94451017.0
# 4509      2025-12-13   98744682.0
# 4770      2025-12-13   98736686.0
# 5211      2026-01-09  100378018.0
# 5880      2025-12-08   98529829.0
# 6040      2025-12-13   98735942.0
# 6926      2026-01-04  100051686.0
# 8273      2025-07-27   93341056.0
# 8389      2025-08-09   93383520.0
# 8453      2025-07-28   93407409.0
# 8770      2025-07-28   93526785.0
# 9117      2025-08-01   93586382.0
# 9138      2025-08-11   93588856.0
# 10191     2025-08-06   93838895.0
# 10265     2025-08-08   93852390.0
# 10818     2025-08-10   93985632.0
# 10951     2025-08-11   94029513.0
#
#                                            Feedback Text
# 1230   lots of mix ups on the day food to another par...
# 1663    the toilets were filthy   hygiene  originality
# 1895   toilets were unfortunately filthy during our v...
# ...

# %%
acquisition_question = "How did you learn of Area 51 Helensvale?"

acquisition_data = df.loc[
    df["Additional Question"].eq(acquisition_question),
    ["Additional Question Answers"]
].copy()

acquisition_data["Channel"] = (
    acquisition_data["Additional Question Answers"]
    .fillna("")
    .astype(str)
    .str.strip()
)

# Keep only answered responses
acquisition_data = acquisition_data[
    acquisition_data["Channel"].ne("")
]

total_acquisition_answers = len(acquisition_data)

acquisition_summary = (
    acquisition_data["Channel"]
    .value_counts()
    .rename_axis("Acquisition Channel")
    .reset_index(name="Responses")
)

acquisition_summary["Percentage"] = (
    acquisition_summary["Responses"]
    / total_acquisition_answers
    * 100
)

display(Markdown(
    f"""
## Customer Acquisition Channels

There were **{total_acquisition_answers:,} answered responses** to:

**“{acquisition_question}”**
"""
))

display(
    acquisition_summary.style
    .format({
        "Responses": "{:,}",
        "Percentage": "{:.1f}%"
    })
    .hide(axis="index")
)
# Out:
# ## Customer Acquisition Channels
#
# There were **462 answered responses** to:
#
# **“How did you learn of Area 51 Helensvale?”**
# <style type="text/css">
# </style>
# <table id="T_782d2">
#   <thead>
#     <tr>
#       <th id="T_782d2_level0_col0" class="col_heading level0 col0" >Acquisition Channel</th>
#       <th id="T_782d2_level0_col1" class="col_heading level0 col1" >Responses</th>
#       <th id="T_782d2_level0_col2" class="col_heading level0 col2" >Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_782d2_row0_col0" class="data row0 col0" >Recommended by friend</td>
#       <td id="T_782d2_row0_col1" class="data row0 col1" >123</td>
#       <td id="T_782d2_row0_col2" class="data row0 col2" >26.6%</td>
#     </tr>
#     <tr>
#       <td id="T_782d2_row1_col0" class="data row1 col0" >Social media</td>
#       <td id="T_782d2_row1_col1" class="data row1 col1" >118</td>
#       <td id="T_782d2_row1_col2" class="data row1 col2" >25.5%</td>
# ...

# %%
chart_data = acquisition_summary.sort_values(
    "Responses",
    ascending=True
)

plt.figure(figsize=(10, 6))

bars = plt.barh(
    chart_data["Acquisition Channel"],
    chart_data["Responses"]
)

for bar, percentage in zip(
    bars,
    chart_data["Percentage"]
):
    plt.text(
        bar.get_width() + 2,
        bar.get_y() + bar.get_height() / 2,
        f"{percentage:.1f}%",
        va="center"
    )

plt.title("How Customers Learned About Area 51 Helensvale")
plt.xlabel("Number of Responses")
plt.ylabel("")
plt.xlim(0, chart_data["Responses"].max() * 1.18)
plt.tight_layout()
plt.show()

# %%
social_question = "Which social media sites interest you?"

social_answers = (
    df.loc[
        df["Additional Question"].eq(social_question),
        "Additional Question Answers"
    ]
    .dropna()
    .astype(str)
    .str.strip()
)

# Remove blank answers
social_answers = social_answers[social_answers.ne("")]

# Number of people who answered this question
total_respondents = len(social_answers)

# Split multiple selections, for example:
# "Facebook, Instagram, TikTok"
platforms = (
    social_answers
    .str.split(r"\s*[,;|]\s*", regex=True)
    .explode()
    .str.strip()
)

platforms = platforms[
    platforms.notna() & platforms.ne("")
]

# Count each platform
social_summary = (
    platforms
    .value_counts()
    .rename_axis("Social Media")
    .reset_index(name="Responses")
)

# Calculate percentage of respondents
social_summary["Percentage"] = (
    social_summary["Responses"]
    / total_respondents
    * 100
)

social_summary = social_summary.sort_values(
    "Percentage",
    ascending=True
)

# Display the data table
display(
    social_summary.sort_values(
        "Percentage",
        ascending=False
    ).style
    .format({
        "Responses": "{:,}",
        "Percentage": "{:.1f}%"
    })
    .hide(axis="index")
)
display(Markdown(
    f"""

There were **{total_social_answers:,} answered responses** to: **“{social_question}”** (Respondents could select more than one platform.)
"""
))
# Out:
# <style type="text/css">
# </style>
# <table id="T_c12cb">
#   <thead>
#     <tr>
#       <th id="T_c12cb_level0_col0" class="col_heading level0 col0" >Social Media</th>
#       <th id="T_c12cb_level0_col1" class="col_heading level0 col1" >Responses</th>
#       <th id="T_c12cb_level0_col2" class="col_heading level0 col2" >Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c12cb_row0_col0" class="data row0 col0" >Facebook</td>
#       <td id="T_c12cb_row0_col1" class="data row0 col1" >241</td>
#       <td id="T_c12cb_row0_col2" class="data row0 col2" >73.3%</td>
#     </tr>
#     <tr>
#       <td id="T_c12cb_row1_col0" class="data row1 col0" >Instagram</td>
#       <td id="T_c12cb_row1_col1" class="data row1 col1" >184</td>
#       <td id="T_c12cb_row1_col2" class="data row1 col2" >55.9%</td>
#     </tr>
#     <tr>
#       <td id="T_c12cb_row2_col0" class="data row2 col0" >TikTok</td>
#       <td id="T_c12cb_row2_col1" class="data row2 col1" >66</td>
# ...

# %%
# Create horizontal bar chart
plt.figure(figsize=(10, 6))

bars = plt.barh(
    social_summary["Social Media"],
    social_summary["Percentage"]
)

# Add percentage labels
for bar, percentage in zip(
    bars,
    social_summary["Percentage"]
):
    plt.text(
        bar.get_width() + 1,
        bar.get_y() + bar.get_height() / 2,
        f"{percentage:.1f}%",
        va="center",
        fontsize=11
    )

plt.title("Social Media Platforms of Interest")
plt.xlabel("Percentage of Respondents")
plt.ylabel("")
plt.xlim(
    0,
    social_summary["Percentage"].max() + 12
)
plt.grid(axis="x", alpha=0.25)
plt.tight_layout()
plt.show()

print(f"Total respondents: {total_respondents:,}")
# Out:
# Total respondents: 329

# %%
import pandas as pd
import re
from IPython.display import display, Markdown

# Customer-facing text only
text_columns = [
    "Comments",
    "Overall Rating Reasons",
    "Service Rating Reasons",
    "Safety Rating Reasons",
    "Facilities Rating Reasons",
    "Value Rating Reasons",
    "Additional Question Comment",
    "Additional Question Answers"
]

available_columns = [
    column for column in text_columns
    if column in df.columns
]

# Combine text separately for each survey row
df["Customer Feedback Text"] = (
    df[available_columns]
    .fillna("")
    .astype(str)
    .agg(" ".join, axis=1)
    .str.replace(r"\s+", " ", regex=True)
    .str.strip()
)

# Competitor-name patterns
competitor_patterns = {
    "Bella's/Belle's Wonderland": (
        r"\b(?:bella|belle)[’']?s?\s+wonderland\b"
    ),

    "EMF / EMF Junior": (
        r"\bemf(?:\s+(?:jnr|junior))?\b"
    ),

    # More specific than simply searching "bounce",
    # because "bounce pad" and "bounce on" are not brand mentions
    "Bounce": (
        r"\bbounce\s+socks?\b|"
        r"\bplaces?\s+like\s+bounce\b|"
        r"\bbounce\s+in\s+broadbeach\b|"
        r"\bother\s+area\s+51\s+venues,\s*bounce\b"
    ),

    "Chipmunks": r"\bchipmunks\b",
    "Lollipops": r"\blollipops\b",
    "iPlay": r"\biplay\b",
    "Timezone": r"\btimezone\b"
}

# Detect each competitor
for competitor, pattern in competitor_patterns.items():
    df[f"Competitor - {competitor}"] = (
        df["Customer Feedback Text"]
        .str.contains(
            pattern,
            case=False,
            regex=True,
            na=False
        )
    )

# Create summary table
competitor_summary = pd.DataFrame([
    {
        "Competitor": competitor,
        "Feedback Rows": int(
            df[f"Competitor - {competitor}"].sum()
        )
    }
    for competitor in competitor_patterns
])

competitor_summary = (
    competitor_summary
    .sort_values("Feedback Rows", ascending=False)
    .reset_index(drop=True)
)

# Identify rows mentioning any competitor
competitor_columns = [
    f"Competitor - {competitor}"
    for competitor in competitor_patterns
]

df["Mentions Competitor"] = (
    df[competitor_columns].any(axis=1)
)

total_competitor_rows = int(
    df["Mentions Competitor"].sum()
)

feedback_rows = int(
    df["Customer Feedback Text"].ne("").sum()
)

percentage = (
    total_competitor_rows / feedback_rows * 100
    if feedback_rows > 0
    else 0
)

display(Markdown(
    f"""
## Competitor Mention Analysis

The survey contains **{total_competitor_rows:,} unique feedback rows**
that mention at least one named competitor.

This represents approximately **{percentage:.1f}%** of the
**{feedback_rows:,} rows containing customer feedback**.
"""
))

display(
    competitor_summary.style
    .format({"Feedback Rows": "{:,}"})
    .hide(axis="index")
)
# Out:
# ## Competitor Mention Analysis
#
# The survey contains **22 unique feedback rows**
# that mention at least one named competitor.
#
# This represents approximately **1.5%** of the
# **1,433 rows containing customer feedback**.
# <style type="text/css">
# </style>
# <table id="T_443c5">
#   <thead>
#     <tr>
#       <th id="T_443c5_level0_col0" class="col_heading level0 col0" >Competitor</th>
#       <th id="T_443c5_level0_col1" class="col_heading level0 col1" >Feedback Rows</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_443c5_row0_col0" class="data row0 col0" >Bella's/Belle's Wonderland</td>
#       <td id="T_443c5_row0_col1" class="data row0 col1" >9</td>
#     </tr>
#     <tr>
#       <td id="T_443c5_row1_col0" class="data row1 col0" >EMF / EMF Junior</td>
#       <td id="T_443c5_row1_col1" class="data row1 col1" >6</td>
#     </tr>
#     <tr>
#       <td id="T_443c5_row2_col0" class="data row2 col0" >Bounce</td>
# ...

# %%
import re
import pandas as pd
from IPython.display import display, Markdown

# Do not truncate long text in Jupyter
pd.set_option("display.max_colwidth", None)

# Terms referring to Area 51 in customer comments
area51_pattern = (
    r"(?:area\s*51|area51|this\s+place|this\s+centre|"
    r"this\s+center|here|us)"
)

# Positive comparative descriptions
positive_comparison = (
    r"(?:better|cheaper|cleaner|bigger|safer|friendlier|"
    r"more\s+affordable|better\s+value|more\s+value|"
    r"less\s+crowded|more\s+spacious)"
)

# Negative comparative descriptions
negative_comparison = (
    r"(?:worse|more\s+expensive|dirtier|smaller|"
    r"less\s+safe|less\s+friendly|poorer\s+value|"
    r"less\s+value|more\s+crowded|not\s+as\s+good)"
)


def judge_competitor(review_text, competitor_pattern):
    """
    Return:
    - Better than us
    - Worse than us
    - Not sure

    The function uses explicit comparative wording only.
    """

    if pd.isna(review_text):
        return "Not sure"

    review_text = str(review_text)

    # Normalise apostrophes
    review_text = (
        review_text
        .replace("’", "'")
        .replace("‘", "'")
    )

    competitor_pattern = f"(?:{competitor_pattern})"

    # Divide the review into sentences
    sentences = re.split(
        r"(?<=[.!?])\s+|\n+",
        review_text
    )

    # Keep sentences mentioning this competitor
    relevant_sentences = [
        sentence
        for sentence in sentences
        if re.search(
            competitor_pattern,
            sentence,
            flags=re.IGNORECASE
        )
    ]

    if not relevant_sentences:
        return "Not sure"

    relevant_text = " ".join(relevant_sentences)

    # -----------------------------------
    # Competitor appears better than us
    # -----------------------------------

    better_patterns = [
        # Bounce is cheaper/better than Area 51
        rf"{competitor_pattern}.{{0,120}}"
        rf"{positive_comparison}.{{0,80}}"
        rf"(?:than|compared\s+(?:with|to)).{{0,80}}"
        rf"{area51_pattern}",

        # Area 51 is more expensive/worse than Bounce
        rf"{area51_pattern}.{{0,120}}"
        rf"{negative_comparison}.{{0,80}}"
        rf"(?:than|compared\s+(?:with|to)).{{0,80}}"
        rf"{competitor_pattern}",

        # Prefer Bounce over Area 51
        rf"(?:prefer|preferred|would\s+choose|rather\s+go\s+to)"
        rf".{{0,80}}{competitor_pattern}"
        rf".{{0,80}}(?:over|instead\s+of|rather\s+than)"
        rf".{{0,80}}{area51_pattern}",
    ]

    # -----------------------------------
    # Competitor appears worse than us
    # -----------------------------------

    worse_patterns = [
        # Bounce is worse/more expensive than Area 51
        rf"{competitor_pattern}.{{0,120}}"
        rf"{negative_comparison}.{{0,80}}"
        rf"(?:than|compared\s+(?:with|to)).{{0,80}}"
        rf"{area51_pattern}",

        # Area 51 is better/cheaper than Bounce
        rf"{area51_pattern}.{{0,120}}"
        rf"{positive_comparison}.{{0,80}}"
        rf"(?:than|compared\s+(?:with|to)).{{0,80}}"
        rf"{competitor_pattern}",

        # Prefer Area 51 over Bounce
        rf"(?:prefer|preferred|would\s+choose)"
        rf".{{0,80}}{area51_pattern}"
        rf".{{0,80}}(?:over|instead\s+of|rather\s+than)"
        rf".{{0,80}}{competitor_pattern}",
    ]

    competitor_better = any(
        re.search(
            pattern,
            relevant_text,
            flags=re.IGNORECASE
        )
        for pattern in better_patterns
    )

    competitor_worse = any(
        re.search(
            pattern,
            relevant_text,
            flags=re.IGNORECASE
        )
        for pattern in worse_patterns
    )

    if competitor_better and not competitor_worse:
        return "Better than us"

    if competitor_worse and not competitor_better:
        return "Worse than us"

    return "Not sure"

# %%
competitor_review_rows = []

for _, row in df.iterrows():

    review_text = row["Customer Feedback Text"]

    if pd.isna(review_text) or not str(review_text).strip():
        continue

    mentioned_competitors = []

    for competitor, pattern in competitor_patterns.items():

        if re.search(
            pattern,
            str(review_text),
            flags=re.IGNORECASE
        ):
            mentioned_competitors.append(competitor)

    if not mentioned_competitors:
        continue

    # Give each competitor its own judgement
    judgements = []

    for competitor in mentioned_competitors:

        judgement = judge_competitor(
            review_text,
            competitor_patterns[competitor]
        )

        judgements.append(
            f"{competitor}: {judgement}"
        )

    competitor_review_rows.append({
        "Completed Date": row["Completed Date"],
        "Competitors Mentioned": ", ".join(
            mentioned_competitors
        ),
        "Judgement": "; ".join(judgements),
        "Full Review Text": review_text
    })


competitor_review_table = pd.DataFrame(
    competitor_review_rows
)

competitor_review_table = (
    competitor_review_table
    .sort_values(
        "Completed Date",
        ascending=False
    )
    .reset_index(drop=True)
)

# %%
separate_competitor_rows = []

for _, row in competitor_review_table.iterrows():

    competitors = [
        item.strip()
        for item in row["Competitors Mentioned"].split(",")
    ]

    judgement_items = [
        item.strip()
        for item in row["Judgement"].split(";")
    ]

    for competitor, judgement_text in zip(
        competitors,
        judgement_items
    ):
        judgement = judgement_text.split(
            ":",
            maxsplit=1
        )[-1].strip()

        separate_competitor_rows.append({
            "Completed Date": row["Completed Date"],
            "Competitor": competitor,
            "Judgement": judgement,
            "Full Review Text": row["Full Review Text"]
        })


competitor_review_expanded = pd.DataFrame(
    separate_competitor_rows
)

display(
    competitor_review_expanded.style
    .hide(axis="index")
    .format({
        "Completed Date": lambda value: (
            value.strftime("%d %b %Y")
            if pd.notna(value)
            else ""
        )
    })
    .set_properties(
        subset=["Full Review Text"],
        **{
            "text-align": "left",
            "white-space": "pre-wrap",
            "word-wrap": "break-word",
            "min-width": "600px",
            "max-width": "900px",
            "vertical-align": "top"
        }
    )
)
# Out:
# <style type="text/css">
# #T_efad9_row0_col3, #T_efad9_row1_col3, #T_efad9_row2_col3, #T_efad9_row3_col3, #T_efad9_row4_col3, #T_efad9_row5_col3, #T_efad9_row6_col3, #T_efad9_row7_col3, #T_efad9_row8_col3, #T_efad9_row9_col3, #T_efad9_row10_col3, #T_efad9_row11_col3, #T_efad9_row12_col3, #T_efad9_row13_col3, #T_efad9_row14_col3, #T_efad9_row15_col3, #T_efad9_row16_col3, #T_efad9_row17_col3, #T_efad9_row18_col3, #T_efad9_row19_col3, #T_efad9_row20_col3, #T_efad9_row21_col3, #T_efad9_row22_col3, #T_efad9_row23_col3, #T_efad9_row24_col3, #T_efad9_row25_col3, #T_efad9_row26_col3, #T_efad9_row27_col3 {
#   text-align: left;
#   white-space: pre-wrap;
#   word-wrap: break-word;
#   min-width: 600px;
#   max-width: 900px;
#   vertical-align: top;
# }
# </style>
# <table id="T_efad9">
#   <thead>
#     <tr>
#       <th id="T_efad9_level0_col0" class="col_heading level0 col0" >Completed Date</th>
#       <th id="T_efad9_level0_col1" class="col_heading level0 col1" >Competitor</th>
# ...
